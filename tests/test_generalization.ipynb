# %%
# %cd /home/jkliu/Projects/CSAServer
# Out:
# /home/jkliu/Projects/CSAServer
# /home/jkliu/Projects/CSAServer/venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from fastapi.testclient import TestClient
from main import app

client = TestClient(app)
# Out:
# cg_container: INFO     Load cg for org.wikipedia.dev-50480
# cg_container: INFO     Load cg for org.wikipedia.dev-50496_bac
# cg_container: INFO     Load cg for org.woheller69.spritpreise-24
# cg_container: INFO     Load cg for org.wikipedia.dev-50443
# cg_container: INFO     Load cg for org.wikipedia.alpha-50476
# cg_container: INFO     Load cg for com.amaze.filemanager-117
# cg_container: INFO     Load cg for com.zhiliaoapp.musically-2022903010
# cg_container: INFO     Load cg for org.woheller69.spritpreise-18
# cg_container: INFO     Load cg for org.wikipedia.dev-50496
# Main        : INFO     Start logging

# %%
request = client.build_request(
    method="post",
    # url="/keeponly",
    # url="/similar",
    url="/more",
    params={
        "package_name": "org.woheller69.spritpreise",
        # "executed_methods": "",
        "executed_methods": "%3Cint%20com.google.android.material.color.MaterialColors.getColor(android.content.Context%2Cint%2Cint)%3E%2C%3Candroidx.preference.EditTextPreference%24SimpleSummaryProvider%20androidx.preference.EditTextPreference%24SimpleSummaryProvider.getInstance()%3E%2C%3Cboolean%20androidx.appcompat.widget.VectorEnabledTintResources.shouldBeUsed()%3E%2C%3Cjava.util.Map%20kotlin.collections.MapsKt__MapsKt.toMap(java.lang.Iterable)%3E%2C%3Ccom.google.android.material.shape.CornerTreatment%20com.google.android.material.shape.MaterialShapeUtils.createDefaultCornerTreatment()%3E%2C%3Cvoid%20androidx.tracing.TraceApi18Impl.beginSection(java.lang.String)%3E%2C%3Cvoid%20androidx.appcompat.widget.DrawableUtils.fixDrawable(android.graphics.drawable.Drawable)%3E%2C%3Cvoid%20androidx.lifecycle.ViewTreeViewModelStoreOwner.set(android.view.View%2Candroidx.lifecycle.ViewModelStoreOwner)%3E%2C%3Cboolean%20androidx.core.util.ObjectsCompat.equals(java.lang.Object%2Cjava.lang.Object)%3E%2C%3Cvoid%20androidx.appcompat.widget.TooltipCompat%24Api26Impl.setTooltipText(android.view.View%2Cjava.lang.CharSequence)%3E%2C%3Cvoid%20androidx.lifecycle.SavedStateHandleSupport.enableSavedStateHandles(androidx.savedstate.SavedStateRegistryOwner)%3E%2C%3Candroid.content.res.ColorStateList%20androidx.core.content.res.ResourcesCompat%24Api23Impl.getColorStateList(android.content.res.Resources%2Cint%2Candroid.content.res.Resources%24Theme)%3E%2C%3Candroid.graphics.PorterDuff%24Mode%20com.google.android.material.internal.ViewUtils.parseTintMode(int%2Candroid.graphics.PorterDuff%24Mode)%3E%2C%3Candroid.view.PointerIcon%20androidx.core.view.PointerIconCompat%24Api24Impl.getSystemIcon(android.content.Context%2Cint)%3E%2C%3Cvoid%20androidx.core.widget.TextViewCompat%24Api17Impl.setCompoundDrawablesRelative(android.widget.TextView%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable)%3E%2C%3Candroidx.emoji2.text.FontRequestEmojiCompatConfig%20androidx.emoji2.text.DefaultEmojiCompatConfig.create(android.content.Context)%3E%2C%3Cvoid%20androidx.core.view.MenuItemCompat.setContentDescription(android.view.MenuItem%2Cjava.lang.CharSequence)%3E%2C%3Cvoid%20androidx.core.widget.EdgeEffectCompat%24Api21Impl.onPull(android.widget.EdgeEffect%2Cfloat%2Cfloat)%3E%2C%3Candroidx.savedstate.SavedStateRegistryController%20androidx.savedstate.SavedStateRegistryController.create(androidx.savedstate.SavedStateRegistryOwner)%3E%2C%3Cjava.util.Map%20com.android.volley.toolbox.HttpHeaderParser.getCacheHeaders(com.android.volley.Cache%24Entry)%3E%2C%3Ckotlin.Pair%20kotlin.TuplesKt.to(java.lang.Object%2Cjava.lang.Object)%3E%2C%3Cvoid%20androidx.core.widget.TextViewCompat.setCompoundDrawablesRelative(android.widget.TextView%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable)%3E%2C%3Candroidx.core.os.LocaleListCompat%20androidx.core.os.ConfigurationCompat.getLocales(android.content.res.Configuration)%3E%2C%3Cboolean%20androidx.core.view.MotionEventCompat.isFromSource(android.view.MotionEvent%2Cint)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api16Impl.postOnAnimation(android.view.View%2Cjava.lang.Runnable)%3E%2C%3Cvoid%20androidx.lifecycle.LifecycleDispatcher.init(android.content.Context)%3E%2C%3Candroidx.appcompat.app.AppCompatDelegate%20androidx.appcompat.app.AppCompatDelegate.create(android.app.Activity%2Candroidx.appcompat.app.AppCompatCallback)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api20Impl.requestApplyInsets(android.view.View)%3E%2C%3Cbyte%5B%5D%20android.system.IcmpHeaders.createIcmpEchoHdr(boolean%2Cint)%3E%2C%3Candroidx.emoji2.text.SpannableBuilder%20androidx.emoji2.text.SpannableBuilder.create(java.lang.Class%2Cjava.lang.CharSequence)%3E%2C%3Cvoid%20androidx.recyclerview.widget.ViewInfoStore%24InfoRecord.drainCache()%3E%2C%3Candroid.graphics.Typeface%20androidx.core.graphics.TypefaceCompat.create(android.content.Context%2Candroid.graphics.Typeface%2Cint)%3E%2C%3Corg.chromium.base.TraceEvent%20org.chromium.base.TraceEvent.I0(java.lang.String)%3E%2C%3Candroidx.startup.AppInitializer%20androidx.startup.AppInitializer.getInstance(android.content.Context)%3E%2C%3Cint%20androidx.core.widget.TextViewCompat.getMaxLines(android.widget.TextView)%3E%2C%3Cjava.lang.StringBuilder%20W80.a(java.lang.String)%3E%2C%3Cjava.lang.String%20kotlin.text.StringsKt__StringsKt.substringAfterLast%24default(java.lang.String%2Cchar%2Cjava.lang.String%2Cint%2Cjava.lang.Object)%3E%2C%3Candroid.graphics.drawable.Drawable%20com.google.android.material.resources.MaterialResources.getDrawable(android.content.Context%2Candroid.content.res.TypedArray%2Cint)%3E%2C%3Cjava.lang.Object%20androidx.core.util.Preconditions.checkNotNull(java.lang.Object%2Cjava.lang.Object)%3E%2C%3Candroidx.fragment.app.SpecialEffectsController%24Operation%24State%20androidx.fragment.app.SpecialEffectsController%24Operation%24State.from(int)%3E%2C%3Cvoid%20androidx.core.os.TraceCompat%24Api18Impl.beginSection(java.lang.String)%3E%2C%3Cvoid%20androidx.core.view.LayoutInflaterCompat.setFactory2(android.view.LayoutInflater%2Candroid.view.LayoutInflater%24Factory2)%3E%2C%3Ccom.google.android.material.animation.MotionSpec%20com.google.android.material.animation.MotionSpec.createFromAttribute(android.content.Context%2Candroid.content.res.TypedArray%2Cint)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api30Impl.setStateDescription(android.view.View%2Cjava.lang.CharSequence)%3E%2C%3Ccom.android.volley.RequestQueue%20com.android.volley.toolbox.Volley.newRequestQueue(android.content.Context)%3E%2C%3Cint%20androidx.core.view.GravityCompat.getAbsoluteGravity(int%2Cint)%3E%2C%3Cvoid%20androidx.core.content.ContextCompat%24Api16Impl.startActivities(android.content.Context%2Candroid.content.Intent%5B%5D%2Candroid.os.Bundle)%3E%2C%3Cboolean%20org.chromium.base.BuildInfo.a()%3E%2C%3Cvoid%20e90.l(long%2Cjava.lang.String)%3E%2C%3Cvoid%20androidx.appcompat.widget.ViewUtils.makeOptionalFitsSystemWindows(android.view.View)%3E%2C%3Candroid.content.SharedPreferences%20androidx.preference.PreferenceManager.getDefaultSharedPreferences(android.content.Context)%3E%2C%3Candroid.app.Activity%20com.google.android.material.internal.ContextUtils.getActivity(android.content.Context)%3E%2C%3Candroid.graphics.Typeface%20androidx.core.content.res.ResourcesCompat.getFont(android.content.Context%2Cint%2Candroid.util.TypedValue%2Cint%2Candroidx.core.content.res.ResourcesCompat%24FontCallback)%3E%2C%3Candroidx.loader.app.LoaderManagerImpl%24LoaderViewModel%20androidx.loader.app.LoaderManagerImpl%24LoaderViewModel.getInstance(androidx.lifecycle.ViewModelStore)%3E%2C%3Cboolean%20com.google.android.material.resources.MaterialAttributes.resolveBoolean(android.content.Context%2Cint%2Cboolean)%3E%2C%3Clong%20U4.a(android.content.pm.PackageInfo)%3E%2C%3Cvoid%20R80.a(int)%3E%2C%3Cvoid%20androidx.appcompat.widget.TooltipCompat.setTooltipText(android.view.View%2Cjava.lang.CharSequence)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api29Impl.saveAttributeDataForStyleable(android.view.View%2Candroid.content.Context%2Cint%5B%5D%2Candroid.util.AttributeSet%2Candroid.content.res.TypedArray%2Cint%2Cint)%3E%2C%3Cboolean%20Ap.a()%3E%2C%3Candroidx.core.view.WindowInsetsCompat%20androidx.core.view.WindowInsetsCompat.toWindowInsetsCompat(android.view.WindowInsets%2Candroid.view.View)%3E%2C%3Ccom.android.volley.toolbox.DiskBasedCache%24CacheHeader%20com.android.volley.toolbox.DiskBasedCache%24CacheHeader.readHeader(com.android.volley.toolbox.DiskBasedCache%24CountingInputStream)%3E%2C%3Cint%5B%5D%20androidx.core.content.res.GrowingArrayUtils.append(int%5B%5D%2Cint%2Cint)%3E%2C%3Cjava.lang.String%20org.woheller69.spritpreise.ui.Help.StringFormatUtils.formatTimeWithoutZone(android.content.Context%2Clong)%3E%2C%3Cvoid%20androidx.core.app.JobIntentService.enqueueWork(android.content.Context%2Cjava.lang.Class%2Cint%2Candroid.content.Intent)%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.content.res.ResourcesCompat%24Api21Impl.getDrawable(android.content.res.Resources%2Cint%2Candroid.content.res.Resources%24Theme)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api21Impl.setOnApplyWindowInsetsListener(android.view.View%2Candroidx.core.view.OnApplyWindowInsetsListener)%3E%2C%3Corg.woheller69.spritpreise.database.SQLiteHelper%20org.woheller69.spritpreise.database.SQLiteHelper.getInstance(android.content.Context)%3E%2C%3Ccom.google.android.material.animation.MotionTiming%20com.google.android.material.animation.MotionTiming.createFromAnimator(android.animation.ValueAnimator)%3E%2C%3Candroid.content.Context%20androidx.appcompat.widget.TintContextWrapper.wrap(android.content.Context)%3E%2C%3Candroid.content.res.ColorStateList%20com.google.android.material.ripple.RippleUtils.sanitizeRippleDrawableColor(android.content.res.ColorStateList)%3E%2C%3Corg.woheller69.spritpreise.ui.CityFragment%20org.woheller69.spritpreise.ui.CityFragment.newInstance(android.os.Bundle)%3E%2C%3Cvoid%20androidx.lifecycle.ReportFragment%24LifecycleCallbacks.registerIn(android.app.Activity)%3E%2C%3Candroid.os.Handler%20androidx.emoji2.text.ConcurrencyHelpers%24Handler28Impl.createAsync(android.os.Looper)%3E%2C%3Cvoid%20androidx.lifecycle.ReportFragment.injectIfNeededIn(android.app.Activity)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api17Impl.setPaddingRelative(android.view.View%2Cint%2Cint%2Cint%2Cint)%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.graphics.drawable.DrawableCompat.wrap(android.graphics.drawable.Drawable)%3E%2C%3Cvoid%20androidx.lifecycle.ProcessLifecycleOwner.init(android.content.Context)%3E%2C%3Candroidx.customview.widget.ViewDragHelper%20androidx.customview.widget.ViewDragHelper.create(android.view.ViewGroup%2Cfloat%2Candroidx.customview.widget.ViewDragHelper%24Callback)%3E%2C%3Cint%20androidx.core.view.MarginLayoutParamsCompat.getMarginStart(android.view.ViewGroup%24MarginLayoutParams)%3E%2C%3Candroidx.core.graphics.Insets%20androidx.core.graphics.Insets.of(int%2Cint%2Cint%2Cint)%3E%2C%3Candroidx.preference.ListPreference%24SimpleSummaryProvider%20androidx.preference.ListPreference%24SimpleSummaryProvider.getInstance()%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.content.ContextCompat%24Api21Impl.getDrawable(android.content.Context%2Cint)%3E%2C%3Candroid.content.res.ColorStateList%20com.google.android.material.ripple.RippleUtils.convertToRippleDrawableColor(android.content.res.ColorStateList)%3E%2C%3Candroidx.core.app.TaskStackBuilder%20androidx.core.app.TaskStackBuilder.create(android.content.Context)%3E%2C%3Cvoid%20androidx.core.view.GravityCompat%24Api17Impl.apply(int%2Cint%2Cint%2Candroid.graphics.Rect%2Candroid.graphics.Rect%2Cint)%3E%2C%3Cint%20androidx.core.view.MarginLayoutParamsCompat%24Api17Impl.getMarginStart(android.view.ViewGroup%24MarginLayoutParams)%3E%2C%3Candroidx.lifecycle.viewmodel.CreationExtras%20androidx.lifecycle.ViewModelProviderGetKt.defaultCreationExtras(androidx.lifecycle.ViewModelStoreOwner)%3E%2C%3Cint%20androidx.core.math.MathUtils.clamp(int%2Cint%2Cint)%3E%2C%3Cvoid%20androidx.coordinatorlayout.widget.ViewGroupUtils.getDescendantRect(android.view.ViewGroup%2Candroid.view.View%2Candroid.graphics.Rect)%3E%2C%3Candroidx.arch.core.executor.ArchTaskExecutor%20androidx.arch.core.executor.ArchTaskExecutor.getInstance()%3E%2C%3Candroidx.recyclerview.widget.OrientationHelper%20androidx.recyclerview.widget.OrientationHelper.createOrientationHelper(androidx.recyclerview.widget.RecyclerView%24LayoutManager%2Cint)%3E%2C%3Cjava.util.List%20kotlin.collections.ArraysUtilJVM.asList(java.lang.Object%5B%5D)%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.appcompat.content.res.AppCompatResources.getDrawable(android.content.Context%2Cint)%3E%2C%3Candroidx.lifecycle.LifecycleEventObserver%20androidx.lifecycle.Lifecycling.lifecycleEventObserver(java.lang.Object)%3E%2C%3Candroidx.core.view.PointerIconCompat%20androidx.core.view.PointerIconCompat.getSystemIcon(android.content.Context%2Cint)%3E%2C%3Cvoid%20androidx.core.os.TraceCompat.beginSection(java.lang.String)%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.widget.CheckedTextViewCompat%24Api16Impl.getCheckMarkDrawable(android.widget.CheckedTextView)%3E%2C%3Cvoid%20androidx.core.graphics.drawable.DrawableCompat%24Api21Impl.setTintList(android.graphics.drawable.Drawable%2Candroid.content.res.ColorStateList)%3E%2C%3Candroidx.appcompat.widget.ResourceManagerInternal%20androidx.appcompat.widget.ResourceManagerInternal.get()%3E%2C%3Cvoid%20androidx.core.widget.EdgeEffectCompat.onPull(android.widget.EdgeEffect%2Cfloat%2Cfloat)%3E%2C%3Cvoid%20org.woheller69.spritpreise.ui.updater.ViewUpdater.addSubscriber(org.woheller69.spritpreise.ui.updater.IUpdateableCityUI)%3E%2C%3Cjava.lang.String%20org.woheller69.preferences.Utils.getKey(java.lang.String)%3E%2C%3Cjava.lang.String%20MR.a(java.lang.String%2Cjava.lang.String%2Cjava.lang.String)%3E%2C%3Candroid.content.Context%20com.google.android.material.theme.overlay.MaterialThemeOverlay.wrap(android.content.Context%2Candroid.util.AttributeSet%2Cint%2Cint)%3E%2C%3Cbyte%5B%5D%20com.android.volley.toolbox.NetworkUtility.inputStreamToBytes(java.io.InputStream%2Cint%2Ccom.android.volley.toolbox.ByteArrayPool)%3E%2C%3Cboolean%20org.chromium.base.EarlyTraceEvent.e()%3E%2C%3Cint%20androidx.core.view.ViewCompat%24Api26Impl.getImportantForAutofill(android.view.View)%3E%2C%3Candroidx.emoji2.text.EmojiCompat%20androidx.emoji2.text.EmojiCompat.init(androidx.emoji2.text.EmojiCompat%24Config)%3E%2C%3Cboolean%20androidx.core.view.ViewParentCompat.onStartNestedScroll(android.view.ViewParent%2Candroid.view.View%2Candroid.view.View%2Cint%2Cint)%3E%2C%3Cjava.lang.String%20Cp.d()%3E%2C%3Cvoid%20HP.d(java.lang.String%2Cjava.lang.String%2Cjava.lang.Object%5B%5D)%3E%2C%3Candroid.content.res.TypedArray%20com.google.android.material.internal.ThemeEnforcement.obtainStyledAttributes(android.content.Context%2Candroid.util.AttributeSet%2Cint%5B%5D%2Cint%2Cint%2Cint%5B%5D)%3E%2C%3Cvoid%20androidx.activity.ComponentActivity%24Api19Impl.cancelPendingInputEvents(android.view.View)%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.content.ContextCompat.getDrawable(android.content.Context%2Cint)%3E%2C%3Cint%20androidx.core.content.res.TypedArrayUtils.getAttr(android.content.Context%2Cint%2Cint)%3E%2C%3Candroid.os.LocaleList%20androidx.core.os.LocaleListCompat%24Api24Impl.createLocaleList(java.util.Locale%5B%5D)%3E%2C%3Candroid.text.Editable%24Factory%20androidx.emoji2.viewsintegration.EmojiEditableFactory.getInstance()%3E%2C%3Candroid.content.res.ColorStateList%20androidx.core.content.res.ColorStateListInflaterCompat.createFromXml(android.content.res.Resources%2Corg.xmlpull.v1.XmlPullParser%2Candroid.content.res.Resources%24Theme)%3E%2C%3Candroid.os.Handler%20org.chromium.base.ThreadUtils.a()%3E%2C%3Candroid.os.LocaleList%20androidx.core.os.ConfigurationCompat%24Api24Impl.getLocales(android.content.res.Configuration)%3E%2C%3Cint%20androidx.core.widget.TextViewCompat%24Api16Impl.getMaxLines(android.widget.TextView)%3E%2C%3Candroidx.viewpager2.adapter.FragmentViewHolder%20androidx.viewpager2.adapter.FragmentViewHolder.create(android.view.ViewGroup)%3E%2C%3Cfloat%20androidx.core.view.ViewConfigurationCompat.getScaledHorizontalScrollFactor(android.view.ViewConfiguration%2Candroid.content.Context)%3E%2C%3Cvoid%20kotlin.jvm.internal.Intrinsics.checkNotNullParameter(java.lang.Object%2Cjava.lang.String)%3E%2C%3Cint%20androidx.recyclerview.widget.ScrollbarHelper.computeScrollRange(androidx.recyclerview.widget.RecyclerView%24State%2Candroidx.recyclerview.widget.OrientationHelper%2Candroid.view.View%2Candroid.view.View%2Candroidx.recyclerview.widget.RecyclerView%24LayoutManager%2Cboolean)%3E%2C%3Cjava.util.Map%20com.android.volley.toolbox.HttpHeaderParser.toHeaderMap(java.util.List)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat.setOnApplyWindowInsetsListener(android.view.View%2Candroidx.core.view.OnApplyWindowInsetsListener)%3E%2C%3Ccom.android.volley.Response%20com.android.volley.Response.success(java.lang.Object%2Ccom.android.volley.Cache%24Entry)%3E%2C%3Candroidx.fragment.app.FragmentController%20androidx.fragment.app.FragmentController.createController(androidx.fragment.app.FragmentHostCallback)%3E%2C%3Cvoid%20androidx.savedstate.ViewTreeSavedStateRegistryOwner.set(android.view.View%2Candroidx.savedstate.SavedStateRegistryOwner)%3E%2C%3Cjava.util.List%20kotlin.collections.CollectionsKt__CollectionsKt.listOf(java.lang.Object%5B%5D)%3E%2C%3Cvoid%20androidx.lifecycle.ViewTreeLifecycleOwner.set(android.view.View%2Candroidx.lifecycle.LifecycleOwner)%3E%2C%3Candroid.graphics.Insets%20androidx.appcompat.widget.DrawableUtils%24Api29Impl.getOpticalInsets(android.graphics.drawable.Drawable)%3E%2C%3Cboolean%20androidx.core.view.ViewParentCompat%24Api21Impl.onStartNestedScroll(android.view.ViewParent%2Candroid.view.View%2Candroid.view.View%2Cint)%3E%2C%3Cint%20androidx.core.graphics.ColorUtils.setAlphaComponent(int%2Cint)%3E%2C%3Cint%20androidx.recyclerview.widget.ScrollbarHelper.computeScrollOffset(androidx.recyclerview.widget.RecyclerView%24State%2Candroidx.recyclerview.widget.OrientationHelper%2Candroid.view.View%2Candroid.view.View%2Candroidx.recyclerview.widget.RecyclerView%24LayoutManager%2Cboolean%2Cboolean)%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api24Impl.setPointerIcon(android.view.View%2Candroid.view.PointerIcon)%3E%2C%3Cint%20com.google.android.material.animation.AnimationUtils.lerp(int%2Cint%2Cfloat)%3E%2C%3Candroidx.core.os.LocaleListCompat%20androidx.core.os.LocaleListCompat.wrap(android.os.LocaleList)%3E%2C%3Cvoid%20org.woheller69.spritpreise.ui.util.photonApiCall.make(android.content.Context%2Cjava.lang.String%2Cjava.lang.String%2Cjava.lang.String%2Ccom.android.volley.Response%24Listener%2Ccom.android.volley.Response%24ErrorListener)%3E%2C%3Ckotlin.Lazy%20kotlin.LazyKt__LazyJVMKt.lazy(kotlin.jvm.functions.Function0)%3E%2C%3Cvoid%20androidx.tracing.Trace.beginSection(java.lang.String)%3E%2C%3Cint%20androidx.core.graphics.drawable.DrawableCompat%24Api23Impl.getLayoutDirection(android.graphics.drawable.Drawable)%3E%2C%3Candroid.view.inputmethod.InputConnection%20androidx.appcompat.widget.AppCompatHintHelper.onCreateInputConnection(android.view.inputmethod.InputConnection%2Candroid.view.inputmethod.EditorInfo%2Candroid.view.View)%3E%2C%3Cvoid%20androidx.appcompat.widget.AppCompatDrawableManager.preload()%3E%2C%3Candroidx.appcompat.widget.TintTypedArray%20androidx.appcompat.widget.TintTypedArray.obtainStyledAttributes(android.content.Context%2Candroid.util.AttributeSet%2Cint%5B%5D)%3E%2C%3Cfloat%20androidx.cardview.widget.RoundRectDrawableWithShadow.calculateVerticalPadding(float%2Cfloat%2Cboolean)%3E%2C%3Cfloat%20androidx.core.view.ViewConfigurationCompat%24Api26Impl.getScaledHorizontalScrollFactor(android.view.ViewConfiguration)%3E%2C%3Cboolean%20androidx.core.view.ViewCompat%24Api15Impl.hasOnClickListeners(android.view.View)%3E%2C%3Candroidx.core.view.WindowInsetsCompat%20androidx.core.view.ViewCompat%24Api23Impl.getRootWindowInsets(android.view.View)%3E%2C%3Cboolean%20androidx.core.util.ObjectsCompat%24Api19Impl.equals(java.lang.Object%2Cjava.lang.Object)%3E%2C%3Cint%20androidx.core.content.ContextCompat%24Api23Impl.getColor(android.content.Context%2Cint)%3E%2C%3Candroidx.loader.app.LoaderManager%20androidx.loader.app.LoaderManager.getInstance(androidx.lifecycle.LifecycleOwner)%3E%2C%3Ccom.google.android.material.shape.ShapeAppearancePathProvider%20com.google.android.material.shape.ShapeAppearancePathProvider.getInstance()%3E%2C%3Candroid.os.Handler%20androidx.emoji2.text.ConcurrencyHelpers.mainHandlerAsync()%3E%2C%3Candroid.content.Context%20androidx.appcompat.app.AppCompatDelegateImpl%24Api17Impl.createConfigurationContext(android.content.Context%2Candroid.content.res.Configuration)%3E%2C%3Cjava.lang.Class%20kotlin.jvm.JvmClassMappingKt.getJavaClass(kotlin.reflect.KClass)%3E%2C%3Candroidx.fragment.app.FragmentManagerViewModel%20androidx.fragment.app.FragmentManagerViewModel.getInstance(androidx.lifecycle.ViewModelStore)%3E%2C%3Clong%20D4.a()%3E%2C%3Cvoid%20androidx.appcompat.widget.ThemeUtils.checkAppCompatTheme(android.view.View%2Candroid.content.Context)%3E%2C%3Cboolean%20androidx.core.view.ViewCompat%24Api19Impl.isLaidOut(android.view.View)%3E%2C%3Cvoid%20com.google.android.material.appbar.ViewUtilsLollipop.setBoundsViewOutlineProvider(android.view.View)%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.widget.CheckedTextViewCompat.getCheckMarkDrawable(android.widget.CheckedTextView)%3E%2C%3Candroidx.fragment.app.SpecialEffectsController%20androidx.fragment.app.SpecialEffectsController.getOrCreateController(android.view.ViewGroup%2Candroidx.fragment.app.FragmentManager)%3E%2C%3Candroid.content.Context%20androidx.appcompat.view.ContextThemeWrapper%24Api17Impl.createConfigurationContext(androidx.appcompat.view.ContextThemeWrapper%2Candroid.content.res.Configuration)%3E%2C%3Cjava.lang.String%20u4.a()%3E%2C%3Candroidx.appcompat.view.ActionBarPolicy%20androidx.appcompat.view.ActionBarPolicy.get(android.content.Context)%3E%2C%3Cjava.lang.String%20androidx.core.app.NavUtils.getParentActivityName(android.app.Activity)%3E%2C%3Cjava.util.List%20kotlin.collections.ArraysKt___ArraysJvmKt.asList(java.lang.Object%5B%5D)%3E%2C%3Cint%20kotlin.collections.CollectionsKt__IterablesKt.collectionSizeOrDefault(java.lang.Iterable%2Cint)%3E%2C%3Ckotlin.reflect.KClass%20kotlin.jvm.internal.Reflection.getOrCreateKotlinClass(java.lang.Class)%3E%2C%3Cvoid%20jn.i(java.lang.String%5B%5D)%3E%2C%3Cvoid%20org.woheller69.spritpreise.activities.ManageLocationsActivity%242.lambda%24onItemClick%241(android.content.DialogInterface%2Cint)%3E%2C%3Cint%20org.woheller69.spritpreise.activities.AboutActivity.getNavigationDrawerID()%3E",
        "version_code": "24"
    }
    # headers={"Authorization": f"Bearer {access_token}"},
)
response = client.send(request)
print(response.json()["to_remove_methods"])
# Out:
# Main        : INFO     Keep only for org.woheller69.spritpreise with %3Cint%20com.google.android.material.color.MaterialColors.getColor(android.content.Context%2Cint%2Cint)%3E%2C%3Candroidx.preference.EditTextPreference%24SimpleSummaryProvider%20androidx.preference.EditTextPreference%24SimpleSummaryProvider.getInstance()%3E%2C%3Cboolean%20androidx.appcompat.widget.VectorEnabledTintResources.shouldBeUsed()%3E%2C%3Cjava.util.Map%20kotlin.collections.MapsKt__MapsKt.toMap(java.lang.Iterable)%3E%2C%3Ccom.google.android.material.shape.CornerTreatment%20com.google.android.material.shape.MaterialShapeUtils.createDefaultCornerTreatment()%3E%2C%3Cvoid%20androidx.tracing.TraceApi18Impl.beginSection(java.lang.String)%3E%2C%3Cvoid%20androidx.appcompat.widget.DrawableUtils.fixDrawable(android.graphics.drawable.Drawable)%3E%2C%3Cvoid%20androidx.lifecycle.ViewTreeViewModelStoreOwner.set(android.view.View%2Candroidx.lifecycle.ViewModelStoreOwner)%3E%2C%3Cboolean%20androidx.core.util.ObjectsCompat.equ
# ...
