# %%
# %cd /home/jkliu/Projects/CSAServer
# Out:
# /home/jkliu/Projects/CSAServer
# /home/jkliu/Projects/CSAServer/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from fastapi.testclient import TestClient
from main import app

client = TestClient(app)
# Out:
# cg_container: INFO     Load cg for com.amaze.filemanager-117
# cg_container: INFO     Load cg for org.woheller69.spritpreise-24
# cg_container: INFO     Load cg for org.wikipedia.alpha-50476
# cg_container: INFO     Load cg for org.wikipedia.dev-50496
# cg_container: INFO     Load cg for com.zhiliaoapp.musically-2022903010
# cg_container: INFO     Load cg for org.wikipedia.dev-50496_bac
# cg_container: INFO     Load cg for org.wikipedia.dev-50480
# cg_container: INFO     Load cg for org.wikipedia.dev-50443
# cg_container: INFO     Load cg for org.woheller69.spritpreise-18
# Main        : INFO     Start logging

# %%
import os


def sign_align_new_apk(input_apk):
    aligned_apk = input_apk.replace(".apk", "_aligned_tmp.apk")
    output_apk = input_apk.replace(".apk", "_signed.apk")
    temp_file = input_apk.replace(".apk", "_signed.apk.idsig")
    os.system(f"zipalign -f 4 {input_apk} {aligned_apk}")
    os.system(f"apksigner sign --ks Apksigner --ks-pass pass:60948491 --out {output_apk} {aligned_apk}")
    # os.system(f"zip -d {output_apk} META-INF/CERT.SF META-INF/CERT.RSA")
    # os.system(f"mv {output_apk} {input_apk}")
    # os.system(f"rm {aligned_apk}")
    # os.system(f"rm {temp_file}")

# %%
from datetime import datetime
import os

executed_methods = {"executed_methods": "%3Cint%20com.google.android.material.color.MaterialColors.getColor%28android.content.Context%2Cint%2Cint%29%3E%2C%3Candroidx.preference.EditTextPreference%24SimpleSummaryProvider%20androidx.preference.EditTextPreference%24SimpleSummaryProvider.getInstance%28%29%3E%2C%3Cboolean%20androidx.appcompat.widget.VectorEnabledTintResources.shouldBeUsed%28%29%3E%2C%3Cjava.util.Map%20kotlin.collections.MapsKt__MapsKt.toMap%28java.lang.Iterable%29%3E%2C%3Ccom.google.android.material.shape.CornerTreatment%20com.google.android.material.shape.MaterialShapeUtils.createDefaultCornerTreatment%28%29%3E%2C%3Cvoid%20androidx.tracing.TraceApi18Impl.beginSection%28java.lang.String%29%3E%2C%3Cvoid%20androidx.appcompat.widget.DrawableUtils.fixDrawable%28android.graphics.drawable.Drawable%29%3E%2C%3Cvoid%20androidx.lifecycle.ViewTreeViewModelStoreOwner.set%28android.view.View%2Candroidx.lifecycle.ViewModelStoreOwner%29%3E%2C%3Cboolean%20androidx.core.util.ObjectsCompat.equals%28java.lang.Object%2Cjava.lang.Object%29%3E%2C%3Cvoid%20androidx.appcompat.widget.TooltipCompat%24Api26Impl.setTooltipText%28android.view.View%2Cjava.lang.CharSequence%29%3E%2C%3Cvoid%20androidx.lifecycle.SavedStateHandleSupport.enableSavedStateHandles%28androidx.savedstate.SavedStateRegistryOwner%29%3E%2C%3Candroid.content.res.ColorStateList%20androidx.core.content.res.ResourcesCompat%24Api23Impl.getColorStateList%28android.content.res.Resources%2Cint%2Candroid.content.res.Resources%24Theme%29%3E%2C%3Candroid.graphics.PorterDuff%24Mode%20com.google.android.material.internal.ViewUtils.parseTintMode%28int%2Candroid.graphics.PorterDuff%24Mode%29%3E%2C%3Candroid.view.PointerIcon%20androidx.core.view.PointerIconCompat%24Api24Impl.getSystemIcon%28android.content.Context%2Cint%29%3E%2C%3Cvoid%20androidx.core.widget.TextViewCompat%24Api17Impl.setCompoundDrawablesRelative%28android.widget.TextView%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%29%3E%2C%3Candroidx.emoji2.text.FontRequestEmojiCompatConfig%20androidx.emoji2.text.DefaultEmojiCompatConfig.create%28android.content.Context%29%3E%2C%3Cvoid%20androidx.core.view.MenuItemCompat.setContentDescription%28android.view.MenuItem%2Cjava.lang.CharSequence%29%3E%2C%3Cvoid%20androidx.core.widget.EdgeEffectCompat%24Api21Impl.onPull%28android.widget.EdgeEffect%2Cfloat%2Cfloat%29%3E%2C%3Candroidx.savedstate.SavedStateRegistryController%20androidx.savedstate.SavedStateRegistryController.create%28androidx.savedstate.SavedStateRegistryOwner%29%3E%2C%3Cjava.util.Map%20com.android.volley.toolbox.HttpHeaderParser.getCacheHeaders%28com.android.volley.Cache%24Entry%29%3E%2C%3Ckotlin.Pair%20kotlin.TuplesKt.to%28java.lang.Object%2Cjava.lang.Object%29%3E%2C%3Cvoid%20androidx.core.widget.TextViewCompat.setCompoundDrawablesRelative%28android.widget.TextView%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%2Candroid.graphics.drawable.Drawable%29%3E%2C%3Candroidx.core.os.LocaleListCompat%20androidx.core.os.ConfigurationCompat.getLocales%28android.content.res.Configuration%29%3E%2C%3Cboolean%20androidx.core.view.MotionEventCompat.isFromSource%28android.view.MotionEvent%2Cint%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api16Impl.postOnAnimation%28android.view.View%2Cjava.lang.Runnable%29%3E%2C%3Cvoid%20androidx.lifecycle.LifecycleDispatcher.init%28android.content.Context%29%3E%2C%3Candroidx.appcompat.app.AppCompatDelegate%20androidx.appcompat.app.AppCompatDelegate.create%28android.app.Activity%2Candroidx.appcompat.app.AppCompatCallback%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api20Impl.requestApplyInsets%28android.view.View%29%3E%2C%3Cbyte%5B%5D%20android.system.IcmpHeaders.createIcmpEchoHdr%28boolean%2Cint%29%3E%2C%3Candroidx.emoji2.text.SpannableBuilder%20androidx.emoji2.text.SpannableBuilder.create%28java.lang.Class%2Cjava.lang.CharSequence%29%3E%2C%3Cvoid%20androidx.recyclerview.widget.ViewInfoStore%24InfoRecord.drainCache%28%29%3E%2C%3Candroid.graphics.Typeface%20androidx.core.graphics.TypefaceCompat.create%28android.content.Context%2Candroid.graphics.Typeface%2Cint%29%3E%2C%3Corg.chromium.base.TraceEvent%20org.chromium.base.TraceEvent.I0%28java.lang.String%29%3E%2C%3Candroidx.startup.AppInitializer%20androidx.startup.AppInitializer.getInstance%28android.content.Context%29%3E%2C%3Cint%20androidx.core.widget.TextViewCompat.getMaxLines%28android.widget.TextView%29%3E%2C%3Cjava.lang.StringBuilder%20W80.a%28java.lang.String%29%3E%2C%3Cjava.lang.String%20kotlin.text.StringsKt__StringsKt.substringAfterLast%24default%28java.lang.String%2Cchar%2Cjava.lang.String%2Cint%2Cjava.lang.Object%29%3E%2C%3Candroid.graphics.drawable.Drawable%20com.google.android.material.resources.MaterialResources.getDrawable%28android.content.Context%2Candroid.content.res.TypedArray%2Cint%29%3E%2C%3Cjava.lang.Object%20androidx.core.util.Preconditions.checkNotNull%28java.lang.Object%2Cjava.lang.Object%29%3E%2C%3Candroidx.fragment.app.SpecialEffectsController%24Operation%24State%20androidx.fragment.app.SpecialEffectsController%24Operation%24State.from%28int%29%3E%2C%3Cvoid%20androidx.core.os.TraceCompat%24Api18Impl.beginSection%28java.lang.String%29%3E%2C%3Cvoid%20androidx.core.view.LayoutInflaterCompat.setFactory2%28android.view.LayoutInflater%2Candroid.view.LayoutInflater%24Factory2%29%3E%2C%3Ccom.google.android.material.animation.MotionSpec%20com.google.android.material.animation.MotionSpec.createFromAttribute%28android.content.Context%2Candroid.content.res.TypedArray%2Cint%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api30Impl.setStateDescription%28android.view.View%2Cjava.lang.CharSequence%29%3E%2C%3Ccom.android.volley.RequestQueue%20com.android.volley.toolbox.Volley.newRequestQueue%28android.content.Context%29%3E%2C%3Cint%20androidx.core.view.GravityCompat.getAbsoluteGravity%28int%2Cint%29%3E%2C%3Cvoid%20androidx.core.content.ContextCompat%24Api16Impl.startActivities%28android.content.Context%2Candroid.content.Intent%5B%5D%2Candroid.os.Bundle%29%3E%2C%3Cboolean%20org.chromium.base.BuildInfo.a%28%29%3E%2C%3Cvoid%20e90.l%28long%2Cjava.lang.String%29%3E%2C%3Cvoid%20androidx.appcompat.widget.ViewUtils.makeOptionalFitsSystemWindows%28android.view.View%29%3E%2C%3Candroid.content.SharedPreferences%20androidx.preference.PreferenceManager.getDefaultSharedPreferences%28android.content.Context%29%3E%2C%3Candroid.app.Activity%20com.google.android.material.internal.ContextUtils.getActivity%28android.content.Context%29%3E%2C%3Candroid.graphics.Typeface%20androidx.core.content.res.ResourcesCompat.getFont%28android.content.Context%2Cint%2Candroid.util.TypedValue%2Cint%2Candroidx.core.content.res.ResourcesCompat%24FontCallback%29%3E%2C%3Candroidx.loader.app.LoaderManagerImpl%24LoaderViewModel%20androidx.loader.app.LoaderManagerImpl%24LoaderViewModel.getInstance%28androidx.lifecycle.ViewModelStore%29%3E%2C%3Cboolean%20com.google.android.material.resources.MaterialAttributes.resolveBoolean%28android.content.Context%2Cint%2Cboolean%29%3E%2C%3Clong%20U4.a%28android.content.pm.PackageInfo%29%3E%2C%3Cvoid%20R80.a%28int%29%3E%2C%3Cvoid%20androidx.appcompat.widget.TooltipCompat.setTooltipText%28android.view.View%2Cjava.lang.CharSequence%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api29Impl.saveAttributeDataForStyleable%28android.view.View%2Candroid.content.Context%2Cint%5B%5D%2Candroid.util.AttributeSet%2Candroid.content.res.TypedArray%2Cint%2Cint%29%3E%2C%3Cboolean%20Ap.a%28%29%3E%2C%3Candroidx.core.view.WindowInsetsCompat%20androidx.core.view.WindowInsetsCompat.toWindowInsetsCompat%28android.view.WindowInsets%2Candroid.view.View%29%3E%2C%3Ccom.android.volley.toolbox.DiskBasedCache%24CacheHeader%20com.android.volley.toolbox.DiskBasedCache%24CacheHeader.readHeader%28com.android.volley.toolbox.DiskBasedCache%24CountingInputStream%29%3E%2C%3Cint%5B%5D%20androidx.core.content.res.GrowingArrayUtils.append%28int%5B%5D%2Cint%2Cint%29%3E%2C%3Cjava.lang.String%20org.woheller69.spritpreise.ui.Help.StringFormatUtils.formatTimeWithoutZone%28android.content.Context%2Clong%29%3E%2C%3Cvoid%20androidx.core.app.JobIntentService.enqueueWork%28android.content.Context%2Cjava.lang.Class%2Cint%2Candroid.content.Intent%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.content.res.ResourcesCompat%24Api21Impl.getDrawable%28android.content.res.Resources%2Cint%2Candroid.content.res.Resources%24Theme%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api21Impl.setOnApplyWindowInsetsListener%28android.view.View%2Candroidx.core.view.OnApplyWindowInsetsListener%29%3E%2C%3Corg.woheller69.spritpreise.database.SQLiteHelper%20org.woheller69.spritpreise.database.SQLiteHelper.getInstance%28android.content.Context%29%3E%2C%3Ccom.google.android.material.animation.MotionTiming%20com.google.android.material.animation.MotionTiming.createFromAnimator%28android.animation.ValueAnimator%29%3E%2C%3Candroid.content.Context%20androidx.appcompat.widget.TintContextWrapper.wrap%28android.content.Context%29%3E%2C%3Candroid.content.res.ColorStateList%20com.google.android.material.ripple.RippleUtils.sanitizeRippleDrawableColor%28android.content.res.ColorStateList%29%3E%2C%3Corg.woheller69.spritpreise.ui.CityFragment%20org.woheller69.spritpreise.ui.CityFragment.newInstance%28android.os.Bundle%29%3E%2C%3Cvoid%20androidx.lifecycle.ReportFragment%24LifecycleCallbacks.registerIn%28android.app.Activity%29%3E%2C%3Candroid.os.Handler%20androidx.emoji2.text.ConcurrencyHelpers%24Handler28Impl.createAsync%28android.os.Looper%29%3E%2C%3Cvoid%20androidx.lifecycle.ReportFragment.injectIfNeededIn%28android.app.Activity%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api17Impl.setPaddingRelative%28android.view.View%2Cint%2Cint%2Cint%2Cint%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.graphics.drawable.DrawableCompat.wrap%28android.graphics.drawable.Drawable%29%3E%2C%3Cvoid%20androidx.lifecycle.ProcessLifecycleOwner.init%28android.content.Context%29%3E%2C%3Candroidx.customview.widget.ViewDragHelper%20androidx.customview.widget.ViewDragHelper.create%28android.view.ViewGroup%2Cfloat%2Candroidx.customview.widget.ViewDragHelper%24Callback%29%3E%2C%3Cint%20androidx.core.view.MarginLayoutParamsCompat.getMarginStart%28android.view.ViewGroup%24MarginLayoutParams%29%3E%2C%3Candroidx.core.graphics.Insets%20androidx.core.graphics.Insets.of%28int%2Cint%2Cint%2Cint%29%3E%2C%3Candroidx.preference.ListPreference%24SimpleSummaryProvider%20androidx.preference.ListPreference%24SimpleSummaryProvider.getInstance%28%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.content.ContextCompat%24Api21Impl.getDrawable%28android.content.Context%2Cint%29%3E%2C%3Candroid.content.res.ColorStateList%20com.google.android.material.ripple.RippleUtils.convertToRippleDrawableColor%28android.content.res.ColorStateList%29%3E%2C%3Candroidx.core.app.TaskStackBuilder%20androidx.core.app.TaskStackBuilder.create%28android.content.Context%29%3E%2C%3Cvoid%20androidx.core.view.GravityCompat%24Api17Impl.apply%28int%2Cint%2Cint%2Candroid.graphics.Rect%2Candroid.graphics.Rect%2Cint%29%3E%2C%3Cint%20androidx.core.view.MarginLayoutParamsCompat%24Api17Impl.getMarginStart%28android.view.ViewGroup%24MarginLayoutParams%29%3E%2C%3Candroidx.lifecycle.viewmodel.CreationExtras%20androidx.lifecycle.ViewModelProviderGetKt.defaultCreationExtras%28androidx.lifecycle.ViewModelStoreOwner%29%3E%2C%3Cint%20androidx.core.math.MathUtils.clamp%28int%2Cint%2Cint%29%3E%2C%3Cvoid%20androidx.coordinatorlayout.widget.ViewGroupUtils.getDescendantRect%28android.view.ViewGroup%2Candroid.view.View%2Candroid.graphics.Rect%29%3E%2C%3Candroidx.arch.core.executor.ArchTaskExecutor%20androidx.arch.core.executor.ArchTaskExecutor.getInstance%28%29%3E%2C%3Candroidx.recyclerview.widget.OrientationHelper%20androidx.recyclerview.widget.OrientationHelper.createOrientationHelper%28androidx.recyclerview.widget.RecyclerView%24LayoutManager%2Cint%29%3E%2C%3Cjava.util.List%20kotlin.collections.ArraysUtilJVM.asList%28java.lang.Object%5B%5D%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.appcompat.content.res.AppCompatResources.getDrawable%28android.content.Context%2Cint%29%3E%2C%3Candroidx.lifecycle.LifecycleEventObserver%20androidx.lifecycle.Lifecycling.lifecycleEventObserver%28java.lang.Object%29%3E%2C%3Candroidx.core.view.PointerIconCompat%20androidx.core.view.PointerIconCompat.getSystemIcon%28android.content.Context%2Cint%29%3E%2C%3Cvoid%20androidx.core.os.TraceCompat.beginSection%28java.lang.String%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.widget.CheckedTextViewCompat%24Api16Impl.getCheckMarkDrawable%28android.widget.CheckedTextView%29%3E%2C%3Cvoid%20androidx.core.graphics.drawable.DrawableCompat%24Api21Impl.setTintList%28android.graphics.drawable.Drawable%2Candroid.content.res.ColorStateList%29%3E%2C%3Candroidx.appcompat.widget.ResourceManagerInternal%20androidx.appcompat.widget.ResourceManagerInternal.get%28%29%3E%2C%3Cvoid%20androidx.core.widget.EdgeEffectCompat.onPull%28android.widget.EdgeEffect%2Cfloat%2Cfloat%29%3E%2C%3Cvoid%20org.woheller69.spritpreise.ui.updater.ViewUpdater.addSubscriber%28org.woheller69.spritpreise.ui.updater.IUpdateableCityUI%29%3E%2C%3Cjava.lang.String%20org.woheller69.preferences.Utils.getKey%28java.lang.String%29%3E%2C%3Cjava.lang.String%20MR.a%28java.lang.String%2Cjava.lang.String%2Cjava.lang.String%29%3E%2C%3Candroid.content.Context%20com.google.android.material.theme.overlay.MaterialThemeOverlay.wrap%28android.content.Context%2Candroid.util.AttributeSet%2Cint%2Cint%29%3E%2C%3Cbyte%5B%5D%20com.android.volley.toolbox.NetworkUtility.inputStreamToBytes%28java.io.InputStream%2Cint%2Ccom.android.volley.toolbox.ByteArrayPool%29%3E%2C%3Cboolean%20org.chromium.base.EarlyTraceEvent.e%28%29%3E%2C%3Cint%20androidx.core.view.ViewCompat%24Api26Impl.getImportantForAutofill%28android.view.View%29%3E%2C%3Candroidx.emoji2.text.EmojiCompat%20androidx.emoji2.text.EmojiCompat.init%28androidx.emoji2.text.EmojiCompat%24Config%29%3E%2C%3Cboolean%20androidx.core.view.ViewParentCompat.onStartNestedScroll%28android.view.ViewParent%2Candroid.view.View%2Candroid.view.View%2Cint%2Cint%29%3E%2C%3Cjava.lang.String%20Cp.d%28%29%3E%2C%3Cvoid%20HP.d%28java.lang.String%2Cjava.lang.String%2Cjava.lang.Object%5B%5D%29%3E%2C%3Candroid.content.res.TypedArray%20com.google.android.material.internal.ThemeEnforcement.obtainStyledAttributes%28android.content.Context%2Candroid.util.AttributeSet%2Cint%5B%5D%2Cint%2Cint%2Cint%5B%5D%29%3E%2C%3Cvoid%20androidx.activity.ComponentActivity%24Api19Impl.cancelPendingInputEvents%28android.view.View%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.content.ContextCompat.getDrawable%28android.content.Context%2Cint%29%3E%2C%3Cint%20androidx.core.content.res.TypedArrayUtils.getAttr%28android.content.Context%2Cint%2Cint%29%3E%2C%3Candroid.os.LocaleList%20androidx.core.os.LocaleListCompat%24Api24Impl.createLocaleList%28java.util.Locale%5B%5D%29%3E%2C%3Candroid.text.Editable%24Factory%20androidx.emoji2.viewsintegration.EmojiEditableFactory.getInstance%28%29%3E%2C%3Candroid.content.res.ColorStateList%20androidx.core.content.res.ColorStateListInflaterCompat.createFromXml%28android.content.res.Resources%2Corg.xmlpull.v1.XmlPullParser%2Candroid.content.res.Resources%24Theme%29%3E%2C%3Candroid.os.Handler%20org.chromium.base.ThreadUtils.a%28%29%3E%2C%3Candroid.os.LocaleList%20androidx.core.os.ConfigurationCompat%24Api24Impl.getLocales%28android.content.res.Configuration%29%3E%2C%3Cint%20androidx.core.widget.TextViewCompat%24Api16Impl.getMaxLines%28android.widget.TextView%29%3E%2C%3Candroidx.viewpager2.adapter.FragmentViewHolder%20androidx.viewpager2.adapter.FragmentViewHolder.create%28android.view.ViewGroup%29%3E%2C%3Cfloat%20androidx.core.view.ViewConfigurationCompat.getScaledHorizontalScrollFactor%28android.view.ViewConfiguration%2Candroid.content.Context%29%3E%2C%3Cvoid%20kotlin.jvm.internal.Intrinsics.checkNotNullParameter%28java.lang.Object%2Cjava.lang.String%29%3E%2C%3Cint%20androidx.recyclerview.widget.ScrollbarHelper.computeScrollRange%28androidx.recyclerview.widget.RecyclerView%24State%2Candroidx.recyclerview.widget.OrientationHelper%2Candroid.view.View%2Candroid.view.View%2Candroidx.recyclerview.widget.RecyclerView%24LayoutManager%2Cboolean%29%3E%2C%3Cjava.util.Map%20com.android.volley.toolbox.HttpHeaderParser.toHeaderMap%28java.util.List%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat.setOnApplyWindowInsetsListener%28android.view.View%2Candroidx.core.view.OnApplyWindowInsetsListener%29%3E%2C%3Ccom.android.volley.Response%20com.android.volley.Response.success%28java.lang.Object%2Ccom.android.volley.Cache%24Entry%29%3E%2C%3Candroidx.fragment.app.FragmentController%20androidx.fragment.app.FragmentController.createController%28androidx.fragment.app.FragmentHostCallback%29%3E%2C%3Cvoid%20androidx.savedstate.ViewTreeSavedStateRegistryOwner.set%28android.view.View%2Candroidx.savedstate.SavedStateRegistryOwner%29%3E%2C%3Cjava.util.List%20kotlin.collections.CollectionsKt__CollectionsKt.listOf%28java.lang.Object%5B%5D%29%3E%2C%3Cvoid%20androidx.lifecycle.ViewTreeLifecycleOwner.set%28android.view.View%2Candroidx.lifecycle.LifecycleOwner%29%3E%2C%3Candroid.graphics.Insets%20androidx.appcompat.widget.DrawableUtils%24Api29Impl.getOpticalInsets%28android.graphics.drawable.Drawable%29%3E%2C%3Cboolean%20androidx.core.view.ViewParentCompat%24Api21Impl.onStartNestedScroll%28android.view.ViewParent%2Candroid.view.View%2Candroid.view.View%2Cint%29%3E%2C%3Cint%20androidx.core.graphics.ColorUtils.setAlphaComponent%28int%2Cint%29%3E%2C%3Cint%20androidx.recyclerview.widget.ScrollbarHelper.computeScrollOffset%28androidx.recyclerview.widget.RecyclerView%24State%2Candroidx.recyclerview.widget.OrientationHelper%2Candroid.view.View%2Candroid.view.View%2Candroidx.recyclerview.widget.RecyclerView%24LayoutManager%2Cboolean%2Cboolean%29%3E%2C%3Cvoid%20androidx.core.view.ViewCompat%24Api24Impl.setPointerIcon%28android.view.View%2Candroid.view.PointerIcon%29%3E%2C%3Cint%20com.google.android.material.animation.AnimationUtils.lerp%28int%2Cint%2Cfloat%29%3E%2C%3Candroidx.core.os.LocaleListCompat%20androidx.core.os.LocaleListCompat.wrap%28android.os.LocaleList%29%3E%2C%3Cvoid%20org.woheller69.spritpreise.ui.util.photonApiCall.make%28android.content.Context%2Cjava.lang.String%2Cjava.lang.String%2Cjava.lang.String%2Ccom.android.volley.Response%24Listener%2Ccom.android.volley.Response%24ErrorListener%29%3E%2C%3Ckotlin.Lazy%20kotlin.LazyKt__LazyJVMKt.lazy%28kotlin.jvm.functions.Function0%29%3E%2C%3Cvoid%20androidx.tracing.Trace.beginSection%28java.lang.String%29%3E%2C%3Cint%20androidx.core.graphics.drawable.DrawableCompat%24Api23Impl.getLayoutDirection%28android.graphics.drawable.Drawable%29%3E%2C%3Candroid.view.inputmethod.InputConnection%20androidx.appcompat.widget.AppCompatHintHelper.onCreateInputConnection%28android.view.inputmethod.InputConnection%2Candroid.view.inputmethod.EditorInfo%2Candroid.view.View%29%3E%2C%3Cvoid%20androidx.appcompat.widget.AppCompatDrawableManager.preload%28%29%3E%2C%3Candroidx.appcompat.widget.TintTypedArray%20androidx.appcompat.widget.TintTypedArray.obtainStyledAttributes%28android.content.Context%2Candroid.util.AttributeSet%2Cint%5B%5D%29%3E%2C%3Cfloat%20androidx.cardview.widget.RoundRectDrawableWithShadow.calculateVerticalPadding%28float%2Cfloat%2Cboolean%29%3E%2C%3Cfloat%20androidx.core.view.ViewConfigurationCompat%24Api26Impl.getScaledHorizontalScrollFactor%28android.view.ViewConfiguration%29%3E%2C%3Cboolean%20androidx.core.view.ViewCompat%24Api15Impl.hasOnClickListeners%28android.view.View%29%3E%2C%3Candroidx.core.view.WindowInsetsCompat%20androidx.core.view.ViewCompat%24Api23Impl.getRootWindowInsets%28android.view.View%29%3E%2C%3Cboolean%20androidx.core.util.ObjectsCompat%24Api19Impl.equals%28java.lang.Object%2Cjava.lang.Object%29%3E%2C%3Cint%20androidx.core.content.ContextCompat%24Api23Impl.getColor%28android.content.Context%2Cint%29%3E%2C%3Candroidx.loader.app.LoaderManager%20androidx.loader.app.LoaderManager.getInstance%28androidx.lifecycle.LifecycleOwner%29%3E%2C%3Ccom.google.android.material.shape.ShapeAppearancePathProvider%20com.google.android.material.shape.ShapeAppearancePathProvider.getInstance%28%29%3E%2C%3Candroid.os.Handler%20androidx.emoji2.text.ConcurrencyHelpers.mainHandlerAsync%28%29%3E%2C%3Candroid.content.Context%20androidx.appcompat.app.AppCompatDelegateImpl%24Api17Impl.createConfigurationContext%28android.content.Context%2Candroid.content.res.Configuration%29%3E%2C%3Cjava.lang.Class%20kotlin.jvm.JvmClassMappingKt.getJavaClass%28kotlin.reflect.KClass%29%3E%2C%3Candroidx.fragment.app.FragmentManagerViewModel%20androidx.fragment.app.FragmentManagerViewModel.getInstance%28androidx.lifecycle.ViewModelStore%29%3E%2C%3Clong%20D4.a%28%29%3E%2C%3Cvoid%20androidx.appcompat.widget.ThemeUtils.checkAppCompatTheme%28android.view.View%2Candroid.content.Context%29%3E%2C%3Cboolean%20androidx.core.view.ViewCompat%24Api19Impl.isLaidOut%28android.view.View%29%3E%2C%3Cvoid%20com.google.android.material.appbar.ViewUtilsLollipop.setBoundsViewOutlineProvider%28android.view.View%29%3E%2C%3Candroid.graphics.drawable.Drawable%20androidx.core.widget.CheckedTextViewCompat.getCheckMarkDrawable%28android.widget.CheckedTextView%29%3E%2C%3Candroidx.fragment.app.SpecialEffectsController%20androidx.fragment.app.SpecialEffectsController.getOrCreateController%28android.view.ViewGroup%2Candroidx.fragment.app.FragmentManager%29%3E%2C%3Candroid.content.Context%20androidx.appcompat.view.ContextThemeWrapper%24Api17Impl.createConfigurationContext%28androidx.appcompat.view.ContextThemeWrapper%2Candroid.content.res.Configuration%29%3E%2C%3Cjava.lang.String%20u4.a%28%29%3E%2C%3Candroidx.appcompat.view.ActionBarPolicy%20androidx.appcompat.view.ActionBarPolicy.get%28android.content.Context%29%3E%2C%3Cjava.lang.String%20androidx.core.app.NavUtils.getParentActivityName%28android.app.Activity%29%3E%2C%3Cjava.util.List%20kotlin.collections.ArraysKt___ArraysJvmKt.asList%28java.lang.Object%5B%5D%29%3E%2C%3Cint%20kotlin.collections.CollectionsKt__IterablesKt.collectionSizeOrDefault%28java.lang.Iterable%2Cint%29%3E%2C%3Ckotlin.reflect.KClass%20kotlin.jvm.internal.Reflection.getOrCreateKotlinClass%28java.lang.Class%29%3E%2C%3Cvoid%20jn.i%28java.lang.String%5B%5D%29%3E%2C%3Cvoid%20org.woheller69.spritpreise.activities.ManageLocationsActivity%242.lambda%24onItemClick%241%28android.content.DialogInterface%2Cint%29%3E%2C%3Cvoid%20org.woheller69.spritpreise.firststart.TutorialActivity.changeStatusBarColor%28%29%3E%2C%3Candroid.location.LocationListener%20org.woheller69.spritpreise.activities.CityGasPricesActivity.getNewLocationListener%28%29%3E%2C%3Cvoid%20org.woheller69.spritpreise.activities.SplashActivity.onCreate%28android.os.Bundle%29%3E"}

import json

executed_methods_json = json.dumps(executed_methods)

request = client.build_request(
    method="post",
    # url="/keeponly",
    url="/keeponly?package_name=org.woheller69.spritpreise&version_code=24",
    # url="/similar",
    # url="/more",
    # params={
    #     "package_name": "org.woheller69.spritpreise",
    #     "version_code": "24"
    # }
    content=executed_methods_json
    # headers={"Authorization": f"Bearer {access_token}"},
)
response = client.send(request)
print(response.json()["to_remove_methods"])
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_time = current_time.replace(" ", "_")
# with open(f"results/temp_debloated/{current_time}_to_remove.log", "w") as write2filelog:
#     for method in response.json()["to_remove_methods"]:
#         print(method)
#         write2filelog.write(f"{method}\n")

# cmd = f"java -jar lib/debloater.jar -toDebloatPath results/temp_debloated/{current_time}_to_remove.log -androidJar lib/platforms -apkPath apks/org.woheller69.spritpreise-24.apk"
# os.system(cmd)
# sign_align_new_apk("results/temp_debloated/org.woheller69.spritpreise-24.apk")
# Out:
# Main        : INFO     Keep only for org.woheller69.spritpreise with %3Cint%20com.google.android.material.color.MaterialColors.getColor%28android.content.Context%2Cint%2Cint%29%3E%2C%3Candroidx.preference.EditTextPreference%24SimpleSummaryProvider%20androidx.preference.EditTextPreference%24SimpleSummaryProvider.getInstance%28%29%3E%2C%3Cboolean%20androidx.appcompat.widget.VectorEnabledTintResources.shouldBeUsed%28%29%3E%2C%3Cjava.util.Map%20kotlin.collections.MapsKt__MapsKt.toMap%28java.lang.Iterable%29%3E%2C%3Ccom.google.android.material.shape.CornerTreatment%20com.google.android.material.shape.MaterialShapeUtils.createDefaultCornerTreatment%28%29%3E%2C%3Cvoid%20androidx.tracing.TraceApi18Impl.beginSection%28java.lang.String%29%3E%2C%3Cvoid%20androidx.appcompat.widget.DrawableUtils.fixDrawable%28android.graphics.drawable.Drawable%29%3E%2C%3Cvoid%20androidx.lifecycle.ViewTreeViewModelStoreOwner.set%28android.view.View%2Candroidx.lifecycle.ViewModelStoreOwner%29%3E%2C%3Cboolean%20andr
# ...
