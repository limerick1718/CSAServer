# %%
# %cd /home/jkliu/Projects/CSAServer
# Out:
# /home/jkliu/Projects/CSAServer
# /home/jkliu/Projects/CSAServer/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os

dir = "/home/jkliu/Projects/CSAServer"
for root, dirs, files in os.walk(dir):
    for file in files:
        if file.endswith(':Zone.Identifier'):
            file_path = os.path.join(root, file)
            print(file_path)
            os.system(f"rm -f {file_path}")
# Out:
# /home/jkliu/Projects/CSAServer/main.py:Zone.Identifier
# /home/jkliu/Projects/CSAServer/AndroidCallbacks.txt:Zone.Identifier
# /home/jkliu/Projects/CSAServer/config.py:Zone.Identifier
# /home/jkliu/Projects/CSAServer/apk_package.sh:Zone.Identifier
# /home/jkliu/Projects/CSAServer/similarity_cal.py:Zone.Identifier
# /home/jkliu/Projects/CSAServer/.gitignore:Zone.Identifier
# /home/jkliu/Projects/CSAServer/Apksigner:Zone.Identifier
# /home/jkliu/Projects/CSAServer/example.txt:Zone.Identifier
# /home/jkliu/Projects/CSAServer/wiki_example.ipynb:Zone.Identifier
# /home/jkliu/Projects/CSAServer/screenshotcleaner.ipynb:Zone.Identifier
# /home/jkliu/Projects/CSAServer/requirements.txt:Zone.Identifier
# /home/jkliu/Projects/CSAServer/config/config.json:Zone.Identifier
# /home/jkliu/Projects/CSAServer/config/mappings/permission_new.txt:Zone.Identifier
# /home/jkliu/Projects/CSAServer/config/mappings/permission_api.txt:Zone.Identifier
# ...
